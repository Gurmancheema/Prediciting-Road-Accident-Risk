# %% [markdown]
# ### 1. Importing libraries to fetch data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/train.csv')
df.head(20)
# Out:
#     id road_type  num_lanes  curvature  speed_limit  lighting weather  \
# 0    0     urban          2       0.06           35  daylight   rainy
# 1    1     urban          4       0.99           35  daylight   clear
# 2    2     rural          4       0.63           70       dim   clear
# 3    3   highway          4       0.07           35       dim   rainy
# 4    4     rural          1       0.58           60  daylight   foggy
# 5    5   highway          3       0.54           70     night   foggy
# 6    6   highway          1       0.04           45     night   foggy
# 7    7   highway          2       0.33           45  daylight   clear
# 8    8     rural          3       0.63           25       dim   clear
# 9    9     urban          4       0.38           45       dim   clear
# 10  10   highway          1       0.45           45       dim   clear
# 11  11   highway          4       0.26           60  daylight   foggy
# ...

# %% [markdown]
# ### 2. Fetching more info on dataset

# %%
print("No. of rows & cols. are :",df.shape)
# Out:
# No. of rows & cols. are : (517754, 14)

# %%
print("Summary of numerical cols. of dataset\n",df.describe())
# Out:
# Summary of numerical cols. of dataset
#                    id      num_lanes      curvature    speed_limit  \
# count  517754.000000  517754.000000  517754.000000  517754.000000
# mean   258876.500000       2.491511       0.488719      46.112575
# std    149462.849974       1.120434       0.272563      15.788521
# min         0.000000       1.000000       0.000000      25.000000
# 25%    129438.250000       1.000000       0.260000      35.000000
# 50%    258876.500000       2.000000       0.510000      45.000000
# 75%    388314.750000       3.000000       0.710000      60.000000
# max    517753.000000       4.000000       1.000000      70.000000
#
#        num_reported_accidents  accident_risk
# count           517754.000000  517754.000000
# mean                 1.187970       0.352377
# std                  0.895961       0.166417
# min                  0.000000       0.000000
# 25%                  1.000000       0.230000
# 50%                  1.000000       0.340000
# ...

# %% [markdown]
# ### 3. Checking for missing & duplicate values in dataset

# %%
df.isnull().sum()
# Out:
# id                        0
# road_type                 0
# num_lanes                 0
# curvature                 0
# speed_limit               0
# lighting                  0
# weather                   0
# road_signs_present        0
# public_road               0
# time_of_day               0
# holiday                   0
# school_season             0
# num_reported_accidents    0
# accident_risk             0
# dtype: int64

# %%
print("No. of duplicate rows in the dataset: ",df.duplicated().sum())
# Out:
# No. of duplicate rows in the dataset:  0

# %% [markdown]
# #### 4. Let's learn more about the types of datatypes of columns

# %%
categorical_cols = df.select_dtypes(include=['object','category','boolean'])
categorical_cols
# Out:
#        road_type  lighting weather  road_signs_present  public_road  \
# 0          urban  daylight   rainy               False         True
# 1          urban  daylight   clear                True        False
# 2          rural       dim   clear               False         True
# 3        highway       dim   rainy                True         True
# 4          rural  daylight   foggy               False        False
# ...          ...       ...     ...                 ...          ...
# 517749   highway  daylight   foggy                True         True
# 517750     rural  daylight   rainy                True         True
# 517751     urban  daylight   foggy               False        False
# 517752   highway     night   clear                True        False
# 517753   highway       dim   rainy               False         True
#
#        time_of_day  holiday  school_season
# 0        afternoon    False           True
# 1          evening     True           True
# ...

# %%
numerical_cols = df.select_dtypes(include =['int','float'])
numerical_cols
# Out:
#             id  num_lanes  curvature  speed_limit  num_reported_accidents  \
# 0            0          2       0.06           35                       1
# 1            1          4       0.99           35                       0
# 2            2          4       0.63           70                       2
# 3            3          4       0.07           35                       1
# 4            4          1       0.58           60                       1
# ...        ...        ...        ...          ...                     ...
# 517749  517749          4       0.10           70                       2
# 517750  517750          4       0.47           35                       1
# 517751  517751          4       0.62           25                       0
# 517752  517752          3       0.63           25                       3
# 517753  517753          2       0.31           45                       2
#
#         accident_risk
# 0                0.13
# 1                0.35
# ...

# %% [markdown]
# # Since there are no duplicates, null values & incorrect datatypes in this dataset, I would move on to perform EDA in the next notebook.
